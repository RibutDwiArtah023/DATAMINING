# %% [markdown]
# #**Linear Regression**

# %% [markdown]
# Senin, 14 November 2022

# %%
from sklearn.datasets import make_regression
from matplotlib import pyplot
X_test, y_test = make_regression(n_samples=20, n_features=1, noise=2)
pyplot.scatter(X_test,y_test)
pyplot.show()

# %%
x = X_test.tolist()
y = y_test.tolist()

# %%
import pandas as pd
data = {'X' : x,'y' : y}

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                         X          y
# 0  [-0.08391724782833648]  -3.581105
# 1    [1.5598812585986213]  59.685183
# 2     [-1.75929815973774] -65.002239
# 3    [0.4221823887392919]  15.195042
# 4   [0.34599833694774795]  13.159600

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
# X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
# y = 1 * x_0 + 2 * x_1 + 3
# y = np.dot(X, np.array([1, 2])) + 3
reg = LinearRegression().fit(X_test, y_test)
reg.score(X_test, y_test)
# Out:
# 0.9976166023622605

# %%
reg.coef_
# Out:
# array([37.18521321])

# %%
reg.intercept_
# Out:
# 0.34208848490127464

# %%
reg.predict(np.array([[2]]))
# Out:
# array([74.71251491])

# %%
pyplot.scatter(X_test, y_test)
Y_plot = reg.coef_*X_test
